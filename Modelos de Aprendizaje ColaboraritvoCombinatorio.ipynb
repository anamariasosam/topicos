# %% [markdown]
# # Bosques Aleatorio
#
#
# ## Arboles de decision/predictivos
#
#
# Hay nodo raiz, los arcos de rama nos llevan a los nodos internos.
#
# Nodo: caracteristicas/atributos color de ojos, altura,
#
# Arcos de rama: cualitativos/cuantitativos verdes, cafe
#
# Hojas: Son las etiquetas
#
# Cada que aumnetamos un nivel tratamos de disminuir la incertidumbre. Entre más arriba mayor la incertidumbre
#
#
# ## Entropía
#
# Mientras mas grande es la entropía mas grande es la incertidumbre
#
# Necesito que me de la menor entropía posible!!!
#
#
# Entropia(D)
#
# D: conjunto de datos
# P/N: Clases
#
# ## Ganancia de información
#
# Se toman las decisiones, con la Entropia
#
#
#
# # Pasos
# 1. Tomamos el conjunto de entrenamiento
#
# Observaciones: Cielo, Temperatura, Humedad Viento
# Etiqueta: Jugar tenis
#
#
# 2. separo entrenamiento y test
#
# ## tabla de datos
# | D1  | SOL    | ALTA  | DEBIL   | - |
# |-----|--------|-------|---------|---|
# | D2  | SOL    | ALTA  | FUERTE  | - |
# | D3  | NUBES  | ALTA  | DEBIL   | + |
# | D5  | LLUVIA | SUAVE | DEBIL   | + |
# | D6  | LLUVIA | BAJA  | DEBIL   | + |
# | D7  | LLUVIA | BAJA  | FUERTE  | - |
# | D8  | NUBE   | BAJA  | FUERTE  | + |
# | D9  | SOL    | SUAVE | DEBIL   | - |
# | D10 | SOL    | BAJA  | DEBIL   | + |
# | D11 | LLUVIA | SUAVE | DEBIL   | + |
# | D12 | SOL    | SUAVE | FUERTE  | + |
# | D13 | NUBE   | SUAVE | FUERTE  | + |
# | D14 | NUBE   | ALTA  | DEBIL   | + |
# | D15 | LLUVIA   | SUAVE | FUERTE  | - |
#
#
#
# Entropia(D) En(9,5)= (-9/14)*log2(9/14) -(5/14)*log2(5/14)
